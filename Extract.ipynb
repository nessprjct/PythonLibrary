# %%
import pandas as pd

class ExtExcel:
    def __init__(self, path):
        self.path = path
        self.data_dict = {}

    def data(self, sheet_name, skiprows, usecols):
        return pd.read_excel(self.path, sheet_name=sheet_name, skiprows=skiprows, usecols=usecols)

    def dropna(self, df):
        df.dropna(how='all', inplace=True, axis=0)
        df.dropna(how='all', inplace=True, axis=1)
        return df.fillna("")

    def get_data(self, df):
        df2 = []
        for i in range(3, len(df.columns)):
            col = df.columns[i]
            if col.startswith('Unnamed'):
                tolM = df.columns[i - 1]
                size = f'{tolM}'
                df1 = df[['Point of Measurement', 'Tol -', 'Tol +', tolM, col]].copy()
                df1.insert(3, 'Size', size)
                df1.rename(columns={df1.columns[4]: 'Mesure', df1.columns[5]: 'Tol'}, inplace=True)
                df2.append(df1)
        return pd.concat(df2, ignore_index=True)

    def get_size(self, df):
        df1 = pd.DataFrame(columns=df.columns)
        for i in df['Size'].unique():
            size = df[df['Size'] == i].head(4)
            df1 = df1.append(size)
        return df1.sort_values(['Point of Measurement', 'Size'], ascending=[False, True])

    def extract(self):
        try:
            df1 = self.data('Trousers', 14, 'A:M')
            df1.rename(columns={df1.columns[1]: 'Tol -', df1.columns[2]: 'Tol +'}, inplace=True)
            df1 = df1.dropna()

            df2 = self.data('Trousers', 2, 'A:F')
            df2 = df2.drop(index=[2, 3]).iloc[:8]
            df2.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1, inplace=True)
            df3 = self.dropna(df2)
            df3.rename(columns={df3.columns[2]: ''}, inplace=True)

            a = df3.columns[1]
            a = pd.to_datetime(a).date()
            df3.columns.values[1] = a
            dict = df3.to_dict()
            # print(dict)


            df4 = self.get_data(df1)
            df5 = self.get_size(df4)

            print(df3, '\n\n')
            print(df5)

        except:
            print('*****FAILED*****')


# exec
df6 = ExtExcel("/content/650095 The O Shape.xlsx")
df6.extract()
# Out:
#                       Date      2023-08-04
# 0                   Saison             223
# 1                       PO          650095
# 4               Style name  05 THE O SHAPE
# 5              Article/col        93608829
# 6                Ready Qty             308  UNITS:
# 7  Measurement sample size              15      cm
# 8           # of OT Points               0
# 9           # of OT Pieces               0
#
#
#    Point of Measurement Tol - Tol +   Size Mesure  Tol
# 32        ½ waist width  -0.7   0.7  24/32  34.75 -0.1
# 0         ½ waist width  -0.7   0.7  26/32  37.25 -0.1
# 8         ½ waist width  -0.7   0.7  27/32   38.5  1.0
# 16        ½ waist width  -0.7   0.7  28/32  39.75 -0.5
# 24        ½ waist width  -0.7   0.7  31/32   43.5 -0.4
# 34        ½ thigh width  -0.7   0.7  24/32  29.25  0.3
# 2         ½ thigh width  -0.7   0.7  26/32  30.55  0.5
# 10        ½ thigh width  -0.7   0.7  27/32   31.2  0.7
# 18        ½ thigh width  -0.7   0.7  28/32  31.85  0.7
# 26        ½ thigh width  -0.7   0.7  31/32     34  0.6
# 33          ½ hip width  -1.2   1.2  24/32  45.75  0.3
# 1           ½ hip width  -1.2   1.2  26/32  48.25  2.3
# 9           ½ hip width  -1.2   1.2  27/32   49.5  1.0
# 17          ½ hip width  -1.2   1.2  28/32  50.75 -0.1
# 25          ½ hip width  -1.2   1.2  31/32   54.5  1.0
# 35     Insde leg length  -1.5   1.5  24/32     72  0.5
# 3      Insde leg length  -1.5   1.5  26/32     72 -0.5
# 11     Insde leg length  -1.5   1.5  27/32     72  1.5
# 19     Insde leg length  -1.5   1.5  28/32     72 -1.3
# 27     Insde leg length  -1.5   1.5  31/32     72 -1.0
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# <ipython-input-4-7a6f9b711c0f>:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(size)
# <ipython-input-4-7a6f9b711c0f>:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(size)
# <ipython-input-4-7a6f9b711c0f>:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(size)
# <ipython-input-4-7a6f9b711c0f>:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(size)
# <ipython-input-4-7a6f9b711c0f>:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(size)
